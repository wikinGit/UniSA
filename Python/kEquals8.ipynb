# %%
k=8
while k>0:
    print(" "*(k-1)+"*"*k)
    k-=1
k=1
while k<9:
    print(" "*(k-1)+"*"*k)
    k+=1
# Out:
#        ********
#       *******
#      ******
#     *****
#    ****
#   ***
#  **
# *
# *
#  **
#   ***
#    ****
#     *****
#      ******
#       *******
#        ********
